# %% [markdown]
# # Posterior Estimation - Sinusoidal model

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import LSTM
from scipy.stats import norm
from scipy.integrate import dblquad
import random

from bayesflow.networks import InvertibleNetwork
from bayesflow.amortizers import SingleModelAmortizer
from bayesflow.trainers import ParameterEstimationTrainer
from bayesflow.diagnostics import *
from bayesflow.models import GenerativeModel

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Simulator settings

# %%
def prior(batch_size):
    """
    Samples from the prior 'batch_size' times.
    ----------
    Output:
    theta : np.ndarray of shape (batch_size, theta_dim) 
    """    
    # Prior range: frequency parameter a ~ U(0.1, 1) & shift parameter b ~ N(0, 0.25²)
    freq_samples = np.random.uniform(0.1, 1.0, size=(batch_size, 1))
    shift_samples = np.random.normal(0.0, 0.25, size=(batch_size, 1))
    p_samples = np.c_[freq_samples, shift_samples]
    return p_samples.astype(np.float32)


# Oscillation model        
n_max = 41
n_min = 2
time_points = np.linspace(0, 10, n_max)
sigma = 0.05   # noise standard deviation

# Variable n_obs
def prior_N(n_min=n_min, n_max=n_max):
    """
    Sample the number of observations uniformly (will be called internally at each backprop step)
    """
    return np.random.randint(n_min, n_max + 1)


def batch_simulator(prior_samples, n_obs):   
    """
    Simulate a batch of oscillation model datasets with n_obs observations each
    """    
    n_sim = prior_samples.shape[0]   # batch size    
    sim_data = np.ones((n_sim, n_obs, 1), dtype=np.float32)   # 1 batch consisting of n_sim datasets, each with n_obs observations
    
    for m in range(n_sim):
        a = prior_samples[m, 0]   # frequency
        b = prior_samples[m, 1]   # shift
        sim_data[m, :, 0] = np.sin(a*2*np.pi*time_points[0:n_obs]) + b + np.random.normal(0, sigma, size=n_obs)
        
    return sim_data

# %% [markdown]
# We build an amortized parameter estimation network.

# %%
bf_meta = {
    'n_coupling_layers': 5,
    's_args': {
        'units': [64, 64, 64],
        'activation': 'elu',
        'initializer': 'glorot_uniform',
    },
    't_args': {
        'units': [64, 64, 64],
        'activation': 'elu',
        'initializer': 'glorot_uniform',
    },
    'n_params': 2
}

# %%
summary_net = LSTM(128)
inference_net = InvertibleNetwork(bf_meta)
amortizer = SingleModelAmortizer(inference_net, summary_net)

# %% [markdown]
# We connect the prior and simulator through a *GenerativeModel* class which will take care of forward inference.

# %%
generative_model = GenerativeModel(prior, batch_simulator)

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=2000,
    decay_rate=0.95,
    staircase=True,
)

# %%
trainer = ParameterEstimationTrainer(
    network=amortizer, 
    generative_model=generative_model,
    learning_rate = lr_schedule,
    checkpoint_path = './Osc(2-41)_5ACB_[64,64,64]_LSTM(128)_ckpts',
    max_to_keep=300,
    skip_checks=True
)
# Out:
# Networks loaded from ./Osc(2-41)_5ACB_[64,64,64]_LSTM(128)_ckpts\ckpt-300

# %% [markdown]
# ### Online training

# %%
# %%time
losses = trainer.train_online(epochs=300, iterations_per_epoch=1000, batch_size=128, n_obs=prior_N)
# Out:
# Training epoch 1:   0%|          | 0/50 [00:00<?, ?it/s]
# Wall time: 13.6 s

# %% [markdown]
# epoch: 50, 100, 150, 200, 250, 300
#
# loss (LSTM 64): -9.832, -9.886
#
# loss (LSTM 128): -8.980, -9.556, -9.867, -10.066, -9.997, -9.930

# %% [markdown]
# ## Computational faithfulness

# %%
param_prior = np.array([[0.95, -0.4]])   
n_obs = 41
x_data = batch_simulator(param_prior, n_obs)
n_post_samples = 7500 
param_prior[0]
# Out:
# array([ 0.95, -0.4 ])

# %%
x_data[0,:,0]
# Out:
# array([-0.4164357 ,  0.49710962, -0.32415697, -1.4289786 , -0.6418667 ,
#         0.40876004,  0.02259699, -1.2936889 , -1.0291568 ,  0.42251682,
#         0.25223437, -0.99966073, -1.2633882 ,  0.1288446 ,  0.46709645,
#        -0.80651957, -1.3912287 , -0.1817492 ,  0.6094535 , -0.4312307 ,
#        -1.3999196 , -0.49763343,  0.54116106, -0.25481734, -1.3465486 ,
#        -0.71335214,  0.501558  ,  0.15518096, -1.2300797 , -1.0526407 ,
#         0.30978617,  0.38809282, -0.93721086, -1.2313355 ,  0.0635549 ,
#         0.48494488, -0.77622384, -1.3294134 , -0.13798404,  0.6105231 ,
#        -0.3595536 ], dtype=float32)

# %%
# Data 1
param_prior = np.array([[0.98, -0.59]])
x_data = np.array([[[-0.6598636],[0.42798552]]])

# %%
# Data 2
param_prior = np.array([[0.5, 0.0]])
x_data = np.array([[[0.14737506], [0.63265115], [1.0534916]]])

# %%
# Data 3
param_prior = np.array([[0.25, 0.3]])
x_data = np.zeros((1,n_obs,1))
x_data[0,:,0] = np.array([0.36077157,  0.70042044,  1.0095065 ,  1.1729454 ,  1.418307  ,
        1.2238537 ,  1.0496973 ,  0.69527644,  0.23484041, -0.17282797,
       -0.34856647, -0.5955486 , -0.76005924, -0.6481214 , -0.35285658,
       -0.02717675,  0.29201108,  0.71980083,  0.9370302 ,  1.2685149 ,
        1.3478009 ])

# %%
# Data 4
param_prior = np.array([[0.95, -0.4]])
x_data = np.zeros((1,n_obs,1))
x_data[0,:,0] = np.array([-0.4164357 ,  0.49710962, -0.32415697, -1.4289786 , -0.6418667 ,
        0.40876004,  0.02259699, -1.2936889 , -1.0291568 ,  0.42251682,
        0.25223437, -0.99966073, -1.2633882 ,  0.1288446 ,  0.46709645,
       -0.80651957, -1.3912287 , -0.1817492 ,  0.6094535 , -0.4312307 ,
       -1.3999196 , -0.49763343,  0.54116106, -0.25481734, -1.3465486 ,
       -0.71335214,  0.501558  ,  0.15518096, -1.2300797 , -1.0526407 ,
        0.30978617,  0.38809282, -0.93721086, -1.2313355 ,  0.0635549 ,
        0.48494488, -0.77622384, -1.3294134 , -0.13798404,  0.6105231 ,
       -0.3595536 ])

# %%
param_samples = amortizer.sample(x_data, n_post_samples)   # BayesFlow samples from the learned posterior

# %%
# Posterior predictive check
fig = plt.figure(figsize=(6.5, 4))
plt.rcParams['font.size'] = 12
time_line = np.linspace(0, 10, 501)

for k in range(301):
    a = param_samples[k, 0]   # frequency
    b = param_samples[k, 1]   # shift    
    if k == 0:
        plt.plot(np.array([0]), np.array([0]), color='grey', label='Simulation', linewidth=0.9)
    else: 
        plt.plot(time_line, np.sin(a*2*np.pi*time_line) + b, color='grey', linewidth=0.5, alpha=0.2)

a = param_prior[0, 0]   # frequency
b = param_prior[0, 1]   # shift
plt.plot(time_line, np.sin(a*2*np.pi*time_line) + b, color='black', label='True trajectory')    
plt.plot(time_points[0:n_obs], x_data[0,0:n_obs,0], 'o', color='blue', label='Available data')

plt.xlabel('Time $t$', fontsize=14)
plt.ylabel('Measurement $y$', fontsize=14)
handles, labels = plt.gca().get_legend_handles_labels()
order = [1,2,0]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order], fontsize=12, bbox_to_anchor=(1.4,0.65))
plt.show()
fig.savefig("figures/{}_Re-simulation.png".format('Osc(2-41)_original_epoch300_data4'), dpi=300, bbox_inches='tight')

# %%
def prior_eval(a,b):   
    # Evaluates prior probability p(theta) according to k_1, k_2 ~ N(-0.75, 0.25²) iid.
    if a > 0.1 and a < 1.0:
        return 1/0.9 * norm.pdf(b, 0.0, 0.25)
    else: 
        return 0.

def likelihood(a,b):   
    # Calculates likelihood p(x_{1:N} | theta)
    residual = (x_data[0,0:n_obs,0] - (np.sin(a*2*np.pi*time_points[0:n_obs]) + b))/sigma
    nllh = np.sum(np.log(2*np.pi*sigma**2)+residual**2)/2
    return np.exp(-nllh)

def unnormalized_posterior(a,b):   
    # Evaluates the unnormalized posterior probability p(theta | x_{1:N}) according to Bayes' formula
    return likelihood(a,b) * prior_eval(a,b)

# %%
# scaling factor
mean_sample = np.mean(param_samples, axis=0)
cov_sample = np.cov(param_samples.transpose())
mean_x = mean_sample[0]
mean_y = mean_sample[1]
std_x = np.sqrt(cov_sample[0, 0])
std_y = np.sqrt(cov_sample[1, 1])

scaling_factor = dblquad(unnormalized_posterior, mean_y-10*std_y, mean_y+10*std_y, lambda y: mean_x-10*std_x, lambda y: mean_x+10*std_x)
print(scaling_factor)

# normalized posterior
posterior_xy = lambda x,y: unnormalized_posterior(x,y)/scaling_factor[0]
posterior_eval = lambda theta: posterior_xy(theta[0], theta[1])
posterior_at_prior = posterior_eval(param_prior[0])
print(posterior_at_prior)
# Out:
# (2.9252780743952838e+23, 6617097480270848.0)
# 23993.681363086263

# %%
# Level sets of true posterior
plot_posterior(param_samples=param_samples, posterior_xy=posterior_xy, filename='Osc(2-41)_original_epoch300_data4')

# %%
# simulation-based calibration
params_sbc = prior(10000)
param_samples = np.empty((10000, 250, 2), dtype=np.float32)
for m in range(10000):
    x_sbc = batch_simulator(np.array([params_sbc[m]]), n_obs=prior_N()).astype(np.float32)
    param_samples[m] = amortizer.sample(x_sbc, n_samples=250)
f = plot_sbc(param_samples, params_sbc, param_names=['$a$', '$b$'], filename='Osc(2-41)_original_epoch300')

# %%
# Validation metrics
true_params = prior(500) 
param_samples = np.empty((500, 1000, 2), dtype=np.float32)
for m in range(500):
    x = batch_simulator(np.array([true_params[m]]), n_obs=prior_N()).astype(np.float32)
    param_samples[m] = amortizer.sample(x, n_samples=1000)
param_means = param_samples.mean(axis=1)
f = true_vs_estimated(true_params, param_means, ['$a$', '$b$'], filename='Osc(2-41)_original_epoch300')
